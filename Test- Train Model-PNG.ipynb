# %%
# %load_ext autoreload
# %autoreload 2

# %%
import model_training

# %%
file_base_location = "/media/romulo/3363-3835/spectrograms_128_array/spectrograms_128_array/png"

# %%
model_training.train_model_from_png(file_base_location)
# Out:
# Running fold 1, holding data from /media/romulo/3363-3835/spectrograms_128_array/spectrograms_128_array/png/fold1 and training on the remaining 9
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_4 (Conv2D)            (None, 124, 124, 24)      1824
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 62, 62, 24)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 58, 58, 48)        28848
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 29, 29, 48)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 25, 25, 48)        57648
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 30000)             0
# ...
